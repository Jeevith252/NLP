# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeevith252/NLP/blob/main/TF_IDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "I love pizza",
    "Pizza is the best",
    "I love pasta",
    "Pasta is great"
]

vectorizer = TfidfVectorizer(ngram_range=(1,2))  # ngram can be changed

X = vectorizer.fit_transform(documents)


print("Vocabulary:", vectorizer.get_feature_names_out())
print("\nBoW Matrix:\n", X.toarray())
# Out:
# Vocabulary: ['best' 'great' 'is' 'is great' 'is the' 'love' 'love pasta' 'love pizza'
#  'pasta' 'pasta is' 'pizza' 'pizza is' 'the' 'the best']
#
# BoW Matrix:
#  [[0.         0.         0.         0.         0.         0.52640543
#   0.         0.66767854 0.         0.         0.52640543 0.
#   0.         0.        ]
#  [0.40021825 0.         0.31553666 0.         0.40021825 0.
#   0.         0.         0.         0.         0.31553666 0.40021825
#   0.40021825 0.40021825]
#  [0.         0.         0.         0.         0.         0.52640543
#   0.66767854 0.         0.52640543 0.         0.         0.
#   0.         0.        ]
#  [0.         0.48546061 0.38274272 0.48546061 0.         0.
#   0.         0.         0.38274272 0.48546061 0.         0.
#   0.         0.        ]]
